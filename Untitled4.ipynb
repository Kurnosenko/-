# %% [markdown]
# <a href="https://colab.research.google.com/github/Kurnosenko/-/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pprint
from random import randint
import matplotlib.pyplot as plt
#импортирует библиотеку которая используется для работы с массивами и матрицами
import numpy as np
from scipy import stats
# импортирует библиотеку пандас которая используется для работы с данными в табличной форме
import pandas as pd

df1=pd.read_csv("/content/part_01.csv")
df2=pd.read_csv("/content/part_02.csv")
df3=pd.read_csv("/content/part_03.csv")
df4=pd.read_csv("/content/part_04.csv")
df5=pd.read_csv("/content/part_05.csv")
df6=pd.read_csv("/content/part_06.csv")
df7=pd.read_csv("/content/part_07.csv")
df8=pd.read_csv("/content/part_08.csv")
df9=pd.read_csv("/content/part_09.csv")
df10=pd.read_csv("/content/part_10.csv")
df11=pd.read_csv("/content/part_11.csv")
df12=pd.read_csv("/content/part_12.csv")
#обьединят датафрейм

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
print(df5.shape)
print(df6.shape)
print(df7.shape)
print(df8.shape)
print(df9.shape)
print(df10.shape)
print(df11.shape)
print(df12.shape)
# Out:
# (177595, 30)
# (177595, 12)
# (177595, 30)
# (177595, 14)
# (177595, 11)
# (177595, 24)
# (177595, 14)
# (177595, 30)
# (177595, 30)
# (177595, 24)
# (177595, 12)
# (177595, 11)

# %%
df1
merge(df2, left_on='ID', right_on='ID')
merge(df3, left_on='ID', right_on='ID')
merge(df4, left_on='ID', right_on='ID')
merge(df5, left_on='ID', right_on='ID')
merge(df6, left_on='ID', right_on='ID')
df1 = pd.concat([df7, df8, df9, df10,df11,df12], ignore_index=True)
cd = df1
cd.sort_values(by="ID")
cd.drop_duplicates
cd.head(10)
#print(f"rows: {cd.shape[0]}, columns: {cd.shape[1]}")
#print(cd.duplicated().any())
#cd.info(verbose=True)
cd.APP_COMP_TYPE = cd.APP_COMP_TYPE.str.lower()
#извлекает уникальные значения из столбца и сохраняет их в список
spisok = [x for x in list(cd.APP_COMP_TYPE.unique()) if x == x]
#сортирует список
spisok.sort()
#выводит список
spisok
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-0965c2217965> in <cell line: 1>()
# ----> 1 merge(df1, left_on='ID', right_on='ID')
#       2 merge(df2, left_on='ID', right_on='ID')
#       3 merge(df3, left_on='ID', right_on='ID')
#       4 merge(df4, left_on='ID', right_on='ID')
#       5 merge(df5, left_on='ID', right_on='ID')
#
# NameError: name 'merge' is not defined

# %%
cd.APP_COMP_TYPE.unique()
# Out:
# array([nan, 'private', 'state', 'inter', 'ip'], dtype=object)

# %%
cd.select_dtypes(include='object')
# Out:
#         CLNT_JOB_POSITION CLNT_JOB_POSITION_TYPE CLNT_TRUST_RELATION PACK  \
# 0                     NaN                    NaN                 NaN  O01
# 1                     NaN                    NaN                 NaN  102
# 2            МЕНЕДЖЕР АХД                    NaN                 NaN  102
# 3            РУКОВОДИТЕЛЬ                    NaN                 NaN  K01
# 4                продавец                    NaN                 NaN  105
# ...                   ...                    ...                 ...  ...
# 1065565               NaN                    NaN                 NaN  NaN
# 1065566               NaN                    NaN                 NaN  NaN
# 1065567               NaN                    NaN                 NaN  NaN
# 1065568               NaN                    NaN                 NaN  NaN
# 1065569               NaN                    NaN                 NaN  NaN
#
#         APP_CAR APP_COMP_TYPE APP_DRIVING_LICENSE APP_EDUCATION APP_EMP_TYPE  \
# ...

# %%
cd.	CLNT_JOB_POSITION.unique()
# Out:
# array([nan, 'МЕНЕДЖЕР АХД', 'РУКОВОДИТЕЛЬ', ..., 'Заместитель дирекотра',
#        'ПОМОЩНИК ПРЕДСЕДАТЕЛЯ ПРАВЛЕНИЯ', 'СТ АДМИНИСТРАТОР'],
#       dtype=object)

# %%
cd = cd.replace('RELATIVE', '', regex=True)

# %%
cd.APP_MARITAL_STATUS.unique()
# Out:
# array([nan, 'M', 'D', 'V', 'T', 'm', 'N', 'v', 'd', 't', 'W', 'C', ' ',
#        'w'], dtype=object)

# %%
cd = cd.replace('продавец', 'покупатель', regex=True)

# %%
cd = cd.replace('ПОМОЩНИК ПРЕДСЕДАТЕЛЯ ПРАВЛЕНИЯ', 'ASSISTANT TO THE CHAIRMAN OF THE MANAGEMENT BOARD', regex=True)

# %%
cd.APP_COMP_TYPE.unique()
# Out:
# array([nan, 'private', 'state', 'inter', 'ip'], dtype=object)
